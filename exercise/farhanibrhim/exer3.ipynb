# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/python-tutorial/blob/main/exercise/farhanibrhim/exer3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/farhanibrhim.txt', 'w') as f:
  f.write('Hello Farhan Ibrahim!')
# !cat /content/drive/My\ Drive/farhanibrhim.txt

drive.flush_and_unmount()
# Out:
# Hello Farhan Ibrahim!

# %%
import pandas as pd

path = "/content/drive/MyDrive/Colab Notebooks/dataset/stories.csv"

df = pd.read_csv(path)

df #displays dataframe
# Out:
#                       _id/$oid  \
# 0     4ba267dc238d3ba3ca000001
# 1     4ba267dc238d3ba3ca000003
# 2     4ba267dc238d3ba3ca000004
# 3     4ba267dc238d3ba3ca000005
# 4     4ba267dc238d3ba3ca000006
# ...                        ...
# 9837  4ba281d4238d3ba3ca00270c
# 9838  4ba281d4238d3ba3ca00270d
# 9839  4ba281d4238d3ba3ca00270e
# 9840  4ba281d4238d3ba3ca00270f
# 9841  4ba281d4238d3ba3ca002710
#
#                                                    href  \
# 0     http://digg.com/people/Jedi_believer_who_refus...
# 1     http://digg.com/odd_stuff/Man_Assaulted_Female...
# 2     http://digg.com/pets_animals/Can_Killer_Whales...
# 3     http://digg.com/general_sciences/Study_Today_s...
# 4     http://digg.com/travel_places/11_Amazing_Treeh...
# ...                                                 ...
# 9837  http://digg.com/television/The_Simpsons_Celebr...
# 9838  http://digg.com/general_sciences/Classified_Re...
# 9839  http://digg.com/politics/Joe_Biden_Criticized_...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9842 entries, 0 to 9841
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   _id/$oid                             9842 non-null   object
#  1   href                                 9842 non-null   object
#  2   title                                9842 non-null   object
#  3   comments/$numberInt                  9842 non-null   int64
#  4   container/name                       9842 non-null   object
#  5   container/short_name                 9842 non-null   object
#  6   submit_date/$numberInt               9842 non-null   int64
#  7   topic/name                           9842 non-null   object
#  8   topic/short_name                     9842 non-null   object
#  9   promote_date/$numberInt              9842 non-null   int64
#  10  id                                   9274 non-null   float64
# ...

# %%
df.describe()
# Out:
#        comments/$numberInt  submit_date/$numberInt  promote_date/$numberInt  \
# count          9842.000000            9.842000e+03             9.842000e+03
# mean            100.792522            1.266127e+09             1.266187e+09
# std             115.584626            1.649973e+06             1.648397e+06
# min               0.000000            1.263072e+09             1.263306e+09
# 25%              34.000000            1.264627e+09             1.264699e+09
# 50%              62.000000            1.266243e+09             1.266299e+09
# 75%             122.000000            1.267585e+09             1.267652e+09
# max            1864.000000            1.268785e+09             1.268916e+09
#
#                  id  diggs/$numberInt  user/registered/$numberInt  \
# count  9.274000e+03       9842.000000                9.842000e+03
# mean   1.922557e+07        594.613900                1.207136e+09
# std    4.590763e+05        643.670091                3.738239e+07
# ...

# %%
df.hist(bins=50, figsize=(15,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-86b371b29256> in <cell line: 2>()
#       1 df.hist(bins=50, figsize=(15,10))
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined
