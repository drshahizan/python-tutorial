# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/python-tutorial/blob/main/exercise/shinpearll/Exercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/foo.txt

drive.flush_and_unmount()
# Out:
# Hello Google Drive!

# %%
import pandas as pd

path = "/content/Olympic medal.csv"

df = pd.read_csv(path)

df #displays dataframe
# Out:
#        Olympic_name  Year     City Country_code    Country_name  \
# 0      ANTWERP 1920  1920  ANTWERP          USA   United States
# 1      ANTWERP 1920  1920  ANTWERP          USA   United States
# 2      ANTWERP 1920  1920  ANTWERP          USA   United States
# 3      ANTWERP 1920  1920  ANTWERP          USA   United States
# 4        PARIS 1924  1924    PARIS          USA   United States
# ...             ...   ...      ...          ...             ...
# 30363   LONDON 2012  2012   LONDON          NED     Netherlands
# 30364   LONDON 2012  2012   LONDON          BLR         Belarus
# 30365   LONDON 2012  2012   LONDON          NED     Netherlands
# 30366   LONDON 2012  2012   LONDON          ESP           Spain
# 30367   LONDON 2012  2012   LONDON          GBR  United Kingdom
#
#        Country_population  Country_GDP_per_Capita  Sport_ID Sport_name  \
# 0               321418820              56115.7188       219   Aquatics
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30368 entries, 0 to 30367
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Olympic_name            30368 non-null  object
#  1   Year                    30368 non-null  int64
#  2   City                    30368 non-null  object
#  3   Country_code            30368 non-null  object
#  4   Country_name            30368 non-null  object
#  5   Country_population      30368 non-null  int64
#  6   Country_GDP_per_Capita  30368 non-null  float64
#  7   Sport_ID                30368 non-null  int64
#  8   Sport_name              30368 non-null  object
#  9   Sport_Discipline        30368 non-null  object
#  10  Sport_Event             30368 non-null  object
#  11  Sport_Games             30368 non-null  object
#  12  Medal                   30368 non-null  object
#  13  Athlete_name            30368 non-null  object
# ...

# %%
df.describe()
# Out:
#                Year  Country_population  Country_GDP_per_Capita      Sport_ID
# count  30368.000000        3.036800e+04            30368.000000  30368.000000
# mean    1973.046167        1.406937e+08            37686.902101    342.073268
# std       34.666145        2.585441e+08            20075.855259    245.998579
# min     1896.000000        3.753100e+04              277.070000      1.000000
# 25%     1948.000000        1.034865e+07            18002.230500    145.000000
# 50%     1984.000000        6.080208e+07            42311.039100    276.000000
# 75%     2002.000000        1.440968e+08            56115.718800    516.000000
# max     2014.000000        1.371220e+09           167290.906200    849.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Year'].plot(kind='hist', bins=20, title='Year')
# ...
