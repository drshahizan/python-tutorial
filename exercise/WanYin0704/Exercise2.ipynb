# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/python-tutorial/blob/main/exercise/WanYin0704/Exercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
  f.write('Hello Wan Yin!')
# !cat /content/drive/My\ Drive/foo.txt

drive.flush_and_unmount()
# Out:
# Hello Google Drive!Hello Wan Yin!

# %%
import pandas as pd

path = "/content/drive/My Drive/Name/sat_world_and_us_history.csv"

df = pd.read_csv(path)

df #displays dataframe
# Out:
#         id        subject                                             prompt  \
# 0        1  world_history  Sumer and Egypt were similar in all of the fol...
# 1        2  world_history  A follower of the Chinese philosophy of Daoism...
# 2        3  world_history  Which of these was NOT a characteristic of ear...
# 3        4  world_history  Buddhism was founded in part as a response to ...
# 4        5  world_history  The Kush city of Meroe rose to prominence main...
# ...    ...            ...                                                ...
# 1375  1141     us_history       The Election of 2000 was significant because
# 1376  1142     us_history  In his 2001 "War on Terror" speech to Congress...
# 1377  1143     us_history                     Mortgage-backed securities are
# 1378  1144     us_history  George W. Bush's immigration reform policy can...
# 1379  1145     us_history                        The Bush Doctrine refers to
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1380 entries, 0 to 1379
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1380 non-null   int64
#  1   subject  1380 non-null   object
#  2   prompt   1379 non-null   object
#  3   A        1380 non-null   object
#  4   B        1380 non-null   object
#  5   C        1380 non-null   object
#  6   D        1380 non-null   object
#  7   E        1380 non-null   object
#  8   answer   1380 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 97.2+ KB

# %%
df.describe()
# Out:
#                 id
# count  1380.000000
# mean    489.897101
# std     345.637700
# min       1.000000
# 25%     179.750000
# 50%     436.500000
# 75%     792.250000
# max    1145.000000

# %%
df.hist(bins=50, figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'id'}>]], dtype=object)
