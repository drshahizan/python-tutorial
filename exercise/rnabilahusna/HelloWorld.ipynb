# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/python-tutorial/blob/main/exercise/rnabilahusna/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello world
# ## Hello world
# ### Hello world
# #### Hello world

# %% [markdown]
# ## Personal Information
# - **Full Name:** Nabila Husna binti Rosli
# - **Age:** 23 years old
# - **Current Location:** Ampang, Selangor
# - **Email:** [nabilahusna@graduate.utm.my](mailto:nabilahusna@graduate.utm.my)
# - **LinkedIn:** [LinkedIn Profile](https://www.linkedin.com/in/rnabila-husna/)

# %%
import pandas as pd
