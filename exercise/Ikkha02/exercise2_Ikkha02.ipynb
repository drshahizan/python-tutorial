# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/python-tutorial/blob/main/exercise/Ikkha02/exercise2_Ikkha02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Ikmal Bin Khairulezuan!')
# !cat /content/drive/My\ Drive/foo.txt

drive.flush_and_unmount()
# Out:
# Hello Ikmal Bin Khairulezuan!

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/Colab Notebooks/Dataset/SUPERSTORE ORDERS_20162019.xlsx"

df = pd.read_excel(file_path)

df# Display the DataFrame
# Out:
#              Category         City Country/Region      Customer Name  \
# 0           Furniture  Los Angeles  United States    Brosina Hoffman
# 1     Office Supplies  Los Angeles  United States    Brosina Hoffman
# 2          Technology  Los Angeles  United States    Brosina Hoffman
# 3     Office Supplies  Los Angeles  United States    Brosina Hoffman
# 4     Office Supplies  Los Angeles  United States    Brosina Hoffman
# ...               ...          ...            ...                ...
# 2436  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2437  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2438  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2439  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2440       Technology     Lakewood  United States  Eugene Hildebrand
#
#       Discount        Order ID  Postal Code  \
# 0            0  CA-2016-115812        90032
# 1            0  CA-2016-115812        90032
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              Category         City Country/Region      Customer Name  \
# 0           Furniture  Los Angeles  United States    Brosina Hoffman
# 1     Office Supplies  Los Angeles  United States    Brosina Hoffman
# 2          Technology  Los Angeles  United States    Brosina Hoffman
# 3     Office Supplies  Los Angeles  United States    Brosina Hoffman
# 4     Office Supplies  Los Angeles  United States    Brosina Hoffman
# ...               ...          ...            ...                ...
# 2436  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2437  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2438  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2439  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2440       Technology     Lakewood  United States  Eugene Hildebrand
#
#       Discount        Order ID  Postal Code  \
# 0            0  CA-2016-115812        90032
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              Category         City Country/Region      Customer Name  \
# 0           Furniture  Los Angeles  United States    Brosina Hoffman
# 1     Office Supplies  Los Angeles  United States    Brosina Hoffman
# 2          Technology  Los Angeles  United States    Brosina Hoffman
# 3     Office Supplies  Los Angeles  United States    Brosina Hoffman
# 4     Office Supplies  Los Angeles  United States    Brosina Hoffman
# ...               ...          ...            ...                ...
# 2436  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2437  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2438  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2439  Office Supplies  Los Angeles  United States      Marc Harrigan
# 2440       Technology     Lakewood  United States  Eugene Hildebrand
#
#       Discount        Order ID  Postal Code  \
# 0            0  CA-2016-115812        90032
# ...

# %%
df.hist(bins=50, figsize=(15,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-86b371b29256> in <cell line: 2>()
#       1 df.hist(bins=50, figsize=(15,10))
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined
