# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/python-tutorial/blob/main/exercise/harithothman/Exercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/foo.txt

drive.flush_and_unmount()

# %%
import pandas as pd

path = "/content/drive/MyDrive/Colab Notebooks/DATASET/BizRecords.csv"

df = pd.read_csv(path)

df #displays dataframe
# Out:
#     CustomerID                 Name                                   Address
# 0            1        PAMELA WRIGHT       2316 E 5th Ave,Denver,CO 80206-4205
# 1            2         MELISSA RUFF  2753 S Milwaukee St,Denver,CO 80210-6426
# 2            3    CONSTANTI VLASSIS  16911 E Harvard Ave,Aurora,CO 80013-1507
# 3            4         AMY LOCKEMER     3721 S Pitkin Ct,Aurora,CO 80013-3024
# 4            5        DANELL VALDEZ   2925 W College Ave,Denver,CO 80219-6059
# ..         ...                  ...                                       ...
# 85          86            M POMEROY    3057 S Pitkin Way,Aurora,CO 80013-2248
# 86          87  LETRICIA CANDELARIA      1927 E 115th Pl,Denver,CO 80233-2295
# 87          88        MARIA DELGADO    605 S Lowell Blvd,Denver,CO 80219-2710
# 88          89          PEGGY LOCKE     808 S Quitman St,Denver,CO 80219-3240
# 89          90       MARIA GONZALEZ      3883 Quitman St,Denver,CO 80212-2145
#
# [90 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  90 non-null     int64
#  1   Name        90 non-null     object
#  2   Address     90 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#        CustomerID
# count   90.000000
# mean    45.500000
# std     26.124701
# min      1.000000
# 25%     23.250000
# 50%     45.500000
# 75%     67.750000
# max     90.000000

# %%
import matplotlib as plt

df.hist(bins=50, figsize=(15,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-4f35b2e7effb> in <cell line: 4>()
#       2
#       3 df.hist(bins=50, figsize=(15,10))
# ----> 4 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/__init__.py in __getattr__(name)
#     224         if name in props:
#     225             return props[name].__get__(instance)
# --> 226         raise AttributeError(
#     227             f"module {cls.__module__!r} has no attribute {name!r}")
#     228
#
# AttributeError: module 'matplotlib' has no attribute 'show'
